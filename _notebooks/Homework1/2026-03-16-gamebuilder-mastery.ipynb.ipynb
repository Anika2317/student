# %% [raw]
# ---
# layout: post
# title: GameBuilder Mastery - Sprint 6 Portfolio
# description: FA1 SkyKingdom, FA2 Interaction Design, Red Riding Hood Final, CS 111 college credit evidence.
# categories: [Sprint6, GameBuilder, OOP, CS111]
# author: anika
# date: 2026-03-17
# ---

# %% [markdown]
# # GameBuilder Mastery: Sprint 6 Portfolio
# **Anika Seksaria | CSSE Sprint 6 | Mira Costa CS 111 | Spring 2026**
#
# This notebook documents everything I built and learned this trimester.
